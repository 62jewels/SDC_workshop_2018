# %% [markdown]
# # Working With Pandas Data Frames
# ---

# %%
import pandas

df = pandas.read_table("../data/processed_data/gapminder_final.csv")

# %% [markdown]
# * Import the pandas library as pd and read in the csv that we just wrote as a data frame using the `read_csv`.

# %%
import pandas as pd
df = pd.read_csv('../data/processed_data/gapminder_final.csv')
df.to_csv("../data/processed_data/gapminder_final.csv")

# %% [markdown]
# * return the data frame from jupyter to view it (pretty)

# %%
df = pd.read_csv("../data/processed_data/gapminder_final.csv")

# %% [markdown]
# * What if we wanted to break up all the data into files for each continent?
# * What if we wanted to have only one row for each country?
#   * We would have to have columns for each year
#
# ** Don't worry about all of the code in the block below. By the end of this section it will make sense. **

# %%
allcountries_df = pd.read_csv("../data/processed_data/gapminder_final.csv")
df_t = allcountries_df

years = sorted(list(df_t['year'].unique()))
# Convert years to strings

for year in years:
    col_name = "gdpPercap_" + str(year)
    df_t[col_name] = 0

for y in years:
    df_t.loc[df_t.year == y, "gdpPercap_" + str(y)] = df_t["gdpPercap"]

df_t = df_t.groupby(df_t["country"]).max()
df_t["pop2007"] = df_t["pop"]
df_t["lifeExp2007"] = df_t["lifeExp"]

df_t.drop("country", axis=1, inplace=True)
df_t.drop("gdpPercap", axis=1, inplace=True)
df_t.drop("year", axis=1, inplace=True)
df_t.drop("lifeExp", axis=1, inplace=True)

continents = df_t["continent"].unique()

df_t.to_csv("../data/processed_data/gapminder_All.csv")

for continent in continents:
    new_df = df_t.loc[df_t["continent"] == continent]
    newfilename = "gapminder_" + continent + ".csv"
    new_df.to_csv("../data/processed_data/" + newfilename)

# %% [markdown]
# * Check out our data folder after we ran this script. We now have six additional csv files.
#     ~~~
#     * gapminder_All.csv
#     * gapminder_Oceana.csv
#     * gapminder_Europe.csv
#     * gapminder_Asia.csv
#     * gapminder_Americas.csv
#     * gapminder_Africa.csv
#     ~~~

# %% [markdown]
# Lets read in the Africa csv to see how the structure has changed.

# %%
# Read in gapminder_Africa.csv as a data frame
df_africa = pd.read_csv("../data/processed_data/gapminder_Africa.csv")
df_africa
# Out:
#                      country  Unnamed: 0  Unnamed: 0.1          pop continent  \
# 0                    Algeria          35            35   33333216.0    Africa
# 1                     Angola          47            47   12420476.0    Africa
# 2                      Benin         131           131    8078314.0    Africa
# 3                   Botswana         167           167    1639131.0    Africa
# 4               Burkina Faso         203           203   14326203.0    Africa
# 5                    Burundi         215           215    8390505.0    Africa
# 6                   Cameroon         239           239   17696293.0    Africa
# 7   Central African Republic         263           263    4369038.0    Africa
# 8                       Chad         275           275   10238807.0    Africa
# 9                    Comoros         323           323     710960.0    Africa
# 10          Congo, Dem. Rep.         335           335   64606759.0    Africa
# 11               Congo, Rep.         347           347    3800610.0    Africa
# 12             Cote d'Ivoire         371           371   18013409.0    Africa
# 13                  Djibouti         431           431     496374.0    Africa
# 14                     Egypt         467           467   80264543.0    Africa
# 15         Equatorial Guinea         491           491     551201.0    Africa
# 16                   Eritrea         503           503    4906585.0    Africa
# 17                  Ethiopia         515           515   76511887.0    Africa
# 18                     Gabon         551           551    1454867.0    Africa
# 19                    Gambia         563           563    1688359.0    Africa
# 20                     Ghana         587           587   22873338.0    Africa
# 21                    Guinea         623           623    9947814.0    Africa
# 22             Guinea-Bissau         635           635    1472041.0    Africa
# 23                     Kenya         827           827   35610177.0    Africa
# 24                   Lesotho         887           887    2046772.0    Africa
# 25                   Liberia         899           899    3193942.0    Africa
# 26                     Libya         911           911    6036914.0    Africa
# 27                Madagascar         923           923   19167654.0    Africa
# 28                    Malawi         935           935   13327079.0    Africa
# 29                      Mali         959           959   12031795.0    Africa
# 30                Mauritania         971           971    3270065.0    Africa
# 31                 Mauritius         983           983    1250882.0    Africa
# 32                   Morocco        1031          1031   33757175.0    Africa
# 33                Mozambique        1043          1043   19951656.0    Africa
# 34                   Namibia        1067          1067    2055080.0    Africa
# 35                     Niger        1127          1127   12894865.0    Africa
# 36                   Nigeria        1139          1139  135031164.0    Africa
# 37                   Reunion        1271          1271     798094.0    Africa
# 38                    Rwanda        1295          1295    8860588.0    Africa
# 39     Sao Tome and Principe        1307          1307     199579.0    Africa
# 40                   Senegal        1331          1331   12267493.0    Africa
# 41              Sierra Leone        1355          1355    6144562.0    Africa
# 42                   Somalia        1403          1403    9118773.0    Africa
# 43              South Africa        1415          1415   44433622.0    Africa
# 44                     Sudan        1451          1451   42292929.0    Africa
# 45                 Swaziland        1463          1463    1133066.0    Africa
# 46                  Tanzania        1523          1523   38139640.0    Africa
# 47                      Togo        1547          1547    5701579.0    Africa
# 48                   Tunisia        1571          1571   10276158.0    Africa
# 49                    Uganda        1595          1595   29170398.0    Africa
# 50                    Zambia        1691          1691   11746035.0    Africa
# 51                  Zimbabwe        1703          1703   12311143.0    Africa
#
#     gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0      2449.008185     3013.976023     2550.816880     3246.991771
# 1      3520.610273     3827.940465     4269.276742     5522.776375
# 2      1062.752200      959.601080      949.499064     1035.831411
# 3       851.241141      918.232535      983.653976     1214.709294
# 4       543.255241      617.183465      722.512021      794.826560
# 5       339.296459      379.564628      355.203227      412.977514
# 6      1172.667655     1313.048099     1399.607441     1508.453148
# 7      1071.310713     1190.844328     1193.068753     1136.056615
# 8      1178.665927     1308.495577     1389.817618     1196.810565
# 9      1102.990936     1211.148548     1406.648278     1876.029643
# 10      780.542326      905.860230      896.314634      861.593242
# 11     2125.621418     2315.056572     2464.783157     2677.939642
# 12     1388.594732     1500.895925     1728.869428     2052.050473
# 13     2669.529475     2864.969076     3020.989263     3020.050513
# 14     1418.822445     1458.915272     1693.335853     1814.880728
# 15      375.643123      426.096408      582.841971      915.596003
# 16      328.940557      344.161886      380.995843      468.794970
# 17      362.146280      378.904163      419.456416      516.118644
# 18     4293.476475     4976.198099     6631.459222     8358.761987
# 19      485.230659      520.926711      599.650276      734.782912
# 20      911.298937     1043.561537     1190.041118     1125.697160
# 21      510.196492      576.267025      686.373674      708.759541
# 22      299.850319      431.790457      522.034373      715.580640
# 23      853.540919      944.438315      896.966373     1056.736457
# 24      298.846212      335.997115      411.800627      498.639026
# 25      575.572996      620.969990      634.195163      713.603648
# 26     2387.548060     3448.284395     6757.030816    18772.751690
# 27     1443.011715     1589.202750     1643.387110     1634.047282
# 28      369.165080      416.369806      427.901086      495.514781
# 29      452.336981      490.382187      496.174343      545.009887
# 30      743.115910      846.120261     1055.896036     1421.145193
# 31     1967.955707     2034.037981     2529.067487     2475.387562
# 32     1688.203570     1642.002314     1566.353493     1711.044770
# 33      468.526038      495.586833      556.686354      566.669154
# 34     2423.780443     2621.448058     3173.215595     3793.694753
# 35      761.879376      835.523403      997.766113     1054.384891
# 36     1077.281856     1100.592563     1150.927478     1014.514104
# 37     2718.885295     2769.451844     3173.723340     4021.175739
# 38      493.323875      540.289398      597.473073      510.963714
# 39      879.583586      860.736903     1071.551119     1384.840593
# 40     1450.356983     1567.653006     1654.988723     1612.404632
# 41      879.787736     1004.484437     1116.639877     1206.043465
# 42     1135.749842     1258.147413     1369.488336     1284.733180
# 43     4725.295531     5487.104219     5768.729717     7114.477971
# 44     1615.991129     1770.337074     1959.593767     1687.997641
# 45     1148.376626     1244.708364     1856.182125     2613.101665
# 46      716.650072      698.535607      722.003807      848.218657
# 47      859.808657      925.908320     1067.534810     1477.596760
# 48     1468.475631     1395.232468     1660.303210     1932.360167
# 49      734.753484      774.371069      767.271740      908.918522
# 50     1147.388831     1311.956766     1452.725766     1777.077318
# 51      406.884115      518.764268      527.272182      569.795071
#
#     gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# 0      4182.663766     4910.416756     5745.160213     5681.358539
# 1      5473.288005     3008.647355     2756.953672     2430.208311
# 2      1085.796879     1029.161251     1277.897616     1225.856010
# 3      2263.611114     3214.857818     4551.142150     6205.883850
# 4       854.735976      743.387037      807.198586      912.063142
# 5       464.099504      556.103265      559.603231      621.818819
# 6      1684.146528     1783.432873     2367.983282     2602.664206
# 7      1070.013275     1109.374338      956.752991      844.876350
# 8      1104.103987     1133.984950      797.908101      952.386129
# 9      1937.577675     1172.603047     1267.100083     1315.980812
# 10      904.896068      795.757282      673.747818      672.774812
# 11     3213.152683     3259.178978     4879.507522     4201.194937
# 12     2378.201111     2517.736547     2602.710169     2156.956069
# 13     3694.212352     3081.761022     2879.468067     2880.102568
# 14     2024.008147     2785.493582     3503.729636     3885.460710
# 15      672.412257      958.566812      927.825343      966.896815
# 16      514.324208      505.753808      524.875849      521.134133
# 17      566.243944      556.808383      577.860747      573.741314
# 18    11401.948410    21745.573280    15113.361940    11864.408440
# 19      756.086836      884.755251      835.809611      611.658861
# 20     1178.223708      993.223957      876.032569      847.006113
# 21      741.666231      874.685864      857.250358      805.572472
# 22      820.224588      764.725963      838.123967      736.415392
# 23     1222.359968     1267.613204     1348.225791     1361.936856
# 24      496.581592      745.369541      797.263107      773.993214
# 25      803.005454      640.322438      572.199569      506.113857
# 26    21011.497210    21951.211760    17364.275380    11770.589800
# 27     1748.562982     1544.228586     1302.878658     1155.441948
# 28      584.621971      663.223677      632.803921      635.517363
# 29      581.368876      686.395269      618.014064      684.171558
# 30     1586.851781     1497.492223     1481.150189     1421.603576
# 31     2575.484158     3710.982963     3688.037739     4783.586903
# 32     1930.194975     2370.619976     2702.620356     2755.046991
# 33      724.917804      502.319733      462.211415      389.876185
# 34     3746.080948     3876.485958     4191.100511     3693.731337
# 35      954.209236      808.897073      909.722135      668.300023
# 36     1698.388838     1981.951806     1576.973750     1385.029563
# 37     5047.658563     4319.804067     5267.219353     5303.377488
# 38      590.580664      670.080601      881.570647      847.991217
# 39     1532.985254     1737.561657     1890.218117     1516.525457
# 40     1597.712056     1561.769116     1518.479984     1441.720720
# 41     1353.759762     1348.285159     1465.010784     1294.447788
# 42     1254.576127     1450.992513     1176.807031     1093.244963
# 43     7765.962636     8028.651439     8568.266228     7825.823398
# 44     1659.652775     2202.988423     1895.544073     1507.819159
# 45     3364.836625     3781.410618     3895.384018     3984.839812
# 46      915.985059      962.492293      874.242607      831.822079
# 47     1649.660188     1532.776998     1344.577953     1202.201361
# 48     2753.285994     3120.876811     3560.233174     3810.419296
# 49      950.735869      843.733137      682.266227      617.724406
# 50     1773.498265     1588.688299     1408.678565     1213.315116
# 51      799.362176      685.587682      788.855041      706.157306
#
#     gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007  \
# 0      5023.216647     4797.295051     5288.040382     6223.367465
# 1      2627.845685     2277.140884     2773.287312     4797.231267
# 2      1191.207681     1232.975292     1372.877931     1441.284873
# 3      7954.111645     8647.142313    11003.605080    12569.851770
# 4       931.752773      946.294962     1037.645221     1217.032994
# 5       631.699878      463.115148      446.403513      430.070692
# 6      1793.163278     1694.337469     1934.011449     2042.095240
# 7       747.905525      740.506332      738.690607      706.016537
# 8      1058.064300     1004.961353     1156.181860     1704.063724
# 9      1246.907370     1173.618235     1075.811558      986.147879
# 10      457.719181      312.188423      241.165876      277.551859
# 11     4016.239529     3484.164376     3484.061970     3632.557798
# 12     1648.073791     1786.265407     1648.800823     1544.750112
# 13     2377.156192     1895.016984     1908.260867     2082.481567
# 14     3794.755195     4173.181797     4754.604414     5581.180998
# 15     1132.055034     2814.480755     7703.495900    12154.089750
# 16      582.858510      913.470790      765.350001      641.369524
# 17      421.353465      515.889401      530.053532      690.805576
# 18    13522.157520    14722.841880    12521.713920    13206.484520
# 19      665.624413      653.730170      660.585600      752.749726
# 20      925.060154     1005.245812     1111.984578     1327.608910
# 21      794.348438      869.449767      945.583584      942.654211
# 22      745.539871      796.664468      575.704718      579.231743
# 23     1341.921721     1360.485021     1287.514732     1463.249282
# 24      977.486273     1186.147994     1275.184575     1569.331442
# 25      636.622919      609.173951      531.482368      414.507341
# 26     9640.138501     9467.446056     9534.677467    12057.499280
# 27     1040.676190      986.295896      894.637082     1044.770126
# 28      563.200014      692.275810      665.423119      759.349910
# 29      739.014375      790.257985      951.409752     1042.581557
# 30     1361.369784     1483.136136     1579.019543     1803.151496
# 31     6058.253846     7425.705295     9021.815894    10956.991120
# 32     2948.047252     2982.101858     3258.495584     3820.175230
# 33      410.896824      472.346077      633.617947      823.685621
# 34     3804.537999     3899.524260     4072.324751     4811.060429
# 35      581.182725      580.305209      601.074501      619.676892
# 36     1619.848217     1624.941275     1615.286395     2013.977305
# 37     6101.255823     6071.941411     6316.165200     7670.122558
# 38      737.068595      589.944505      785.653765      863.088464
# 39     1428.777814     1339.076036     1353.092390     1598.435089
# 40     1367.899369     1392.368347     1519.635262     1712.472136
# 41     1068.696278      574.648158      699.489713      862.540756
# 42      926.960296      930.596428      882.081822      926.141068
# 43     7225.069258     7479.188244     7710.946444     9269.657808
# 44     1492.197043     1632.210764     1993.398314     2602.394995
# 45     3553.022400     3876.768460     4128.116943     4513.480643
# 46      825.682454      789.186223      899.074211     1107.482182
# 47     1034.298904      982.286924      886.220577      882.969944
# 48     4332.720164     4876.798614     5722.895655     7092.923025
# 49      644.170797      816.559081      927.721002     1056.380121
# 50     1210.884633     1071.353818     1071.613938     1271.211593
# 51      693.420786      792.449960      672.038623      469.709298
#
#         pop2007  lifeExp2007
# 0    33333216.0       72.301
# 1    12420476.0       42.731
# 2     8078314.0       56.728
# 3     1639131.0       63.622
# 4    14326203.0       52.295
# 5     8390505.0       49.580
# 6    17696293.0       54.985
# 7     4369038.0       50.485
# 8    10238807.0       51.724
# 9      710960.0       65.152
# 10   64606759.0       47.804
# 11    3800610.0       57.470
# 12   18013409.0       54.655
# 13     496374.0       54.791
# 14   80264543.0       71.338
# 15     551201.0       51.579
# 16    4906585.0       58.040
# 17   76511887.0       52.947
# 18    1454867.0       61.366
# 19    1688359.0       59.448
# 20   22873338.0       60.022
# 21    9947814.0       56.007
# 22    1472041.0       46.388
# 23   35610177.0       59.339
# 24    2046772.0       59.685
# 25    3193942.0       46.027
# 26    6036914.0       73.952
# 27   19167654.0       59.443
# 28   13327079.0       49.420
# 29   12031795.0       54.467
# 30    3270065.0       64.164
# 31    1250882.0       72.801
# 32   33757175.0       71.164
# 33   19951656.0       46.344
# 34    2055080.0       61.999
# 35   12894865.0       56.867
# 36  135031164.0       47.472
# 37     798094.0       76.442
# 38    8860588.0       46.242
# 39     199579.0       65.528
# 40   12267493.0       63.062
# 41    6144562.0       42.568
# 42    9118773.0       48.159
# 43   44433622.0       61.888
# 44   42292929.0       58.556
# 45    1133066.0       58.474
# 46   38139640.0       52.517
# 47    5701579.0       58.420
# 48   10276158.0       73.923
# 49   29170398.0       51.542
# 50   11746035.0       51.821
# 51   12311143.0       62.351

# %% [markdown]
# We can see that now there is only one row for each country. Lets re-read the file using the index_col parameter

# %%
# Re-read the file using index_cols
df_africa1 = pd.read_csv("../data/processed_data/gapminder_Africa.csv", index_col="country")
df_africa1
# Out:
#                           Unnamed: 0  Unnamed: 0.1          pop continent  \
# country
# Algeria                           35            35   33333216.0    Africa
# Angola                            47            47   12420476.0    Africa
# Benin                            131           131    8078314.0    Africa
# Botswana                         167           167    1639131.0    Africa
# Burkina Faso                     203           203   14326203.0    Africa
# Burundi                          215           215    8390505.0    Africa
# Cameroon                         239           239   17696293.0    Africa
# Central African Republic         263           263    4369038.0    Africa
# Chad                             275           275   10238807.0    Africa
# Comoros                          323           323     710960.0    Africa
# Congo, Dem. Rep.                 335           335   64606759.0    Africa
# Congo, Rep.                      347           347    3800610.0    Africa
# Cote d'Ivoire                    371           371   18013409.0    Africa
# Djibouti                         431           431     496374.0    Africa
# Egypt                            467           467   80264543.0    Africa
# Equatorial Guinea                491           491     551201.0    Africa
# Eritrea                          503           503    4906585.0    Africa
# Ethiopia                         515           515   76511887.0    Africa
# Gabon                            551           551    1454867.0    Africa
# Gambia                           563           563    1688359.0    Africa
# Ghana                            587           587   22873338.0    Africa
# Guinea                           623           623    9947814.0    Africa
# Guinea-Bissau                    635           635    1472041.0    Africa
# Kenya                            827           827   35610177.0    Africa
# Lesotho                          887           887    2046772.0    Africa
# Liberia                          899           899    3193942.0    Africa
# Libya                            911           911    6036914.0    Africa
# Madagascar                       923           923   19167654.0    Africa
# Malawi                           935           935   13327079.0    Africa
# Mali                             959           959   12031795.0    Africa
# Mauritania                       971           971    3270065.0    Africa
# Mauritius                        983           983    1250882.0    Africa
# Morocco                         1031          1031   33757175.0    Africa
# Mozambique                      1043          1043   19951656.0    Africa
# Namibia                         1067          1067    2055080.0    Africa
# Niger                           1127          1127   12894865.0    Africa
# Nigeria                         1139          1139  135031164.0    Africa
# Reunion                         1271          1271     798094.0    Africa
# Rwanda                          1295          1295    8860588.0    Africa
# Sao Tome and Principe           1307          1307     199579.0    Africa
# Senegal                         1331          1331   12267493.0    Africa
# Sierra Leone                    1355          1355    6144562.0    Africa
# Somalia                         1403          1403    9118773.0    Africa
# South Africa                    1415          1415   44433622.0    Africa
# Sudan                           1451          1451   42292929.0    Africa
# Swaziland                       1463          1463    1133066.0    Africa
# Tanzania                        1523          1523   38139640.0    Africa
# Togo                            1547          1547    5701579.0    Africa
# Tunisia                         1571          1571   10276158.0    Africa
# Uganda                          1595          1595   29170398.0    Africa
# Zambia                          1691          1691   11746035.0    Africa
# Zimbabwe                        1703          1703   12311143.0    Africa
#
#                           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria                      2449.008185     3013.976023     2550.816880
# Angola                       3520.610273     3827.940465     4269.276742
# Benin                        1062.752200      959.601080      949.499064
# Botswana                      851.241141      918.232535      983.653976
# Burkina Faso                  543.255241      617.183465      722.512021
# Burundi                       339.296459      379.564628      355.203227
# Cameroon                     1172.667655     1313.048099     1399.607441
# Central African Republic     1071.310713     1190.844328     1193.068753
# Chad                         1178.665927     1308.495577     1389.817618
# Comoros                      1102.990936     1211.148548     1406.648278
# Congo, Dem. Rep.              780.542326      905.860230      896.314634
# Congo, Rep.                  2125.621418     2315.056572     2464.783157
# Cote d'Ivoire                1388.594732     1500.895925     1728.869428
# Djibouti                     2669.529475     2864.969076     3020.989263
# Egypt                        1418.822445     1458.915272     1693.335853
# Equatorial Guinea             375.643123      426.096408      582.841971
# Eritrea                       328.940557      344.161886      380.995843
# Ethiopia                      362.146280      378.904163      419.456416
# Gabon                        4293.476475     4976.198099     6631.459222
# Gambia                        485.230659      520.926711      599.650276
# Ghana                         911.298937     1043.561537     1190.041118
# Guinea                        510.196492      576.267025      686.373674
# Guinea-Bissau                 299.850319      431.790457      522.034373
# Kenya                         853.540919      944.438315      896.966373
# Lesotho                       298.846212      335.997115      411.800627
# Liberia                       575.572996      620.969990      634.195163
# Libya                        2387.548060     3448.284395     6757.030816
# Madagascar                   1443.011715     1589.202750     1643.387110
# Malawi                        369.165080      416.369806      427.901086
# Mali                          452.336981      490.382187      496.174343
# Mauritania                    743.115910      846.120261     1055.896036
# Mauritius                    1967.955707     2034.037981     2529.067487
# Morocco                      1688.203570     1642.002314     1566.353493
# Mozambique                    468.526038      495.586833      556.686354
# Namibia                      2423.780443     2621.448058     3173.215595
# Niger                         761.879376      835.523403      997.766113
# Nigeria                      1077.281856     1100.592563     1150.927478
# Reunion                      2718.885295     2769.451844     3173.723340
# Rwanda                        493.323875      540.289398      597.473073
# Sao Tome and Principe         879.583586      860.736903     1071.551119
# Senegal                      1450.356983     1567.653006     1654.988723
# Sierra Leone                  879.787736     1004.484437     1116.639877
# Somalia                      1135.749842     1258.147413     1369.488336
# South Africa                 4725.295531     5487.104219     5768.729717
# Sudan                        1615.991129     1770.337074     1959.593767
# Swaziland                    1148.376626     1244.708364     1856.182125
# Tanzania                      716.650072      698.535607      722.003807
# Togo                          859.808657      925.908320     1067.534810
# Tunisia                      1468.475631     1395.232468     1660.303210
# Uganda                        734.753484      774.371069      767.271740
# Zambia                       1147.388831     1311.956766     1452.725766
# Zimbabwe                      406.884115      518.764268      527.272182
#
#                           gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Algeria                      3246.991771     4182.663766     4910.416756
# Angola                       5522.776375     5473.288005     3008.647355
# Benin                        1035.831411     1085.796879     1029.161251
# Botswana                     1214.709294     2263.611114     3214.857818
# Burkina Faso                  794.826560      854.735976      743.387037
# Burundi                       412.977514      464.099504      556.103265
# Cameroon                     1508.453148     1684.146528     1783.432873
# Central African Republic     1136.056615     1070.013275     1109.374338
# Chad                         1196.810565     1104.103987     1133.984950
# Comoros                      1876.029643     1937.577675     1172.603047
# Congo, Dem. Rep.              861.593242      904.896068      795.757282
# Congo, Rep.                  2677.939642     3213.152683     3259.178978
# Cote d'Ivoire                2052.050473     2378.201111     2517.736547
# Djibouti                     3020.050513     3694.212352     3081.761022
# Egypt                        1814.880728     2024.008147     2785.493582
# Equatorial Guinea             915.596003      672.412257      958.566812
# Eritrea                       468.794970      514.324208      505.753808
# Ethiopia                      516.118644      566.243944      556.808383
# Gabon                        8358.761987    11401.948410    21745.573280
# Gambia                        734.782912      756.086836      884.755251
# Ghana                        1125.697160     1178.223708      993.223957
# Guinea                        708.759541      741.666231      874.685864
# Guinea-Bissau                 715.580640      820.224588      764.725963
# Kenya                        1056.736457     1222.359968     1267.613204
# Lesotho                       498.639026      496.581592      745.369541
# Liberia                       713.603648      803.005454      640.322438
# Libya                       18772.751690    21011.497210    21951.211760
# Madagascar                   1634.047282     1748.562982     1544.228586
# Malawi                        495.514781      584.621971      663.223677
# Mali                          545.009887      581.368876      686.395269
# Mauritania                   1421.145193     1586.851781     1497.492223
# Mauritius                    2475.387562     2575.484158     3710.982963
# Morocco                      1711.044770     1930.194975     2370.619976
# Mozambique                    566.669154      724.917804      502.319733
# Namibia                      3793.694753     3746.080948     3876.485958
# Niger                        1054.384891      954.209236      808.897073
# Nigeria                      1014.514104     1698.388838     1981.951806
# Reunion                      4021.175739     5047.658563     4319.804067
# Rwanda                        510.963714      590.580664      670.080601
# Sao Tome and Principe        1384.840593     1532.985254     1737.561657
# Senegal                      1612.404632     1597.712056     1561.769116
# Sierra Leone                 1206.043465     1353.759762     1348.285159
# Somalia                      1284.733180     1254.576127     1450.992513
# South Africa                 7114.477971     7765.962636     8028.651439
# Sudan                        1687.997641     1659.652775     2202.988423
# Swaziland                    2613.101665     3364.836625     3781.410618
# Tanzania                      848.218657      915.985059      962.492293
# Togo                         1477.596760     1649.660188     1532.776998
# Tunisia                      1932.360167     2753.285994     3120.876811
# Uganda                        908.918522      950.735869      843.733137
# Zambia                       1777.077318     1773.498265     1588.688299
# Zimbabwe                      569.795071      799.362176      685.587682
#
#                           gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# Algeria                      5745.160213     5681.358539     5023.216647
# Angola                       2756.953672     2430.208311     2627.845685
# Benin                        1277.897616     1225.856010     1191.207681
# Botswana                     4551.142150     6205.883850     7954.111645
# Burkina Faso                  807.198586      912.063142      931.752773
# Burundi                       559.603231      621.818819      631.699878
# Cameroon                     2367.983282     2602.664206     1793.163278
# Central African Republic      956.752991      844.876350      747.905525
# Chad                          797.908101      952.386129     1058.064300
# Comoros                      1267.100083     1315.980812     1246.907370
# Congo, Dem. Rep.              673.747818      672.774812      457.719181
# Congo, Rep.                  4879.507522     4201.194937     4016.239529
# Cote d'Ivoire                2602.710169     2156.956069     1648.073791
# Djibouti                     2879.468067     2880.102568     2377.156192
# Egypt                        3503.729636     3885.460710     3794.755195
# Equatorial Guinea             927.825343      966.896815     1132.055034
# Eritrea                       524.875849      521.134133      582.858510
# Ethiopia                      577.860747      573.741314      421.353465
# Gabon                       15113.361940    11864.408440    13522.157520
# Gambia                        835.809611      611.658861      665.624413
# Ghana                         876.032569      847.006113      925.060154
# Guinea                        857.250358      805.572472      794.348438
# Guinea-Bissau                 838.123967      736.415392      745.539871
# Kenya                        1348.225791     1361.936856     1341.921721
# Lesotho                       797.263107      773.993214      977.486273
# Liberia                       572.199569      506.113857      636.622919
# Libya                       17364.275380    11770.589800     9640.138501
# Madagascar                   1302.878658     1155.441948     1040.676190
# Malawi                        632.803921      635.517363      563.200014
# Mali                          618.014064      684.171558      739.014375
# Mauritania                   1481.150189     1421.603576     1361.369784
# Mauritius                    3688.037739     4783.586903     6058.253846
# Morocco                      2702.620356     2755.046991     2948.047252
# Mozambique                    462.211415      389.876185      410.896824
# Namibia                      4191.100511     3693.731337     3804.537999
# Niger                         909.722135      668.300023      581.182725
# Nigeria                      1576.973750     1385.029563     1619.848217
# Reunion                      5267.219353     5303.377488     6101.255823
# Rwanda                        881.570647      847.991217      737.068595
# Sao Tome and Principe        1890.218117     1516.525457     1428.777814
# Senegal                      1518.479984     1441.720720     1367.899369
# Sierra Leone                 1465.010784     1294.447788     1068.696278
# Somalia                      1176.807031     1093.244963      926.960296
# South Africa                 8568.266228     7825.823398     7225.069258
# Sudan                        1895.544073     1507.819159     1492.197043
# Swaziland                    3895.384018     3984.839812     3553.022400
# Tanzania                      874.242607      831.822079      825.682454
# Togo                         1344.577953     1202.201361     1034.298904
# Tunisia                      3560.233174     3810.419296     4332.720164
# Uganda                        682.266227      617.724406      644.170797
# Zambia                       1408.678565     1213.315116     1210.884633
# Zimbabwe                      788.855041      706.157306      693.420786
#
#                           gdpPercap_1997  gdpPercap_2002  gdpPercap_2007  \
# country
# Algeria                      4797.295051     5288.040382     6223.367465
# Angola                       2277.140884     2773.287312     4797.231267
# Benin                        1232.975292     1372.877931     1441.284873
# Botswana                     8647.142313    11003.605080    12569.851770
# Burkina Faso                  946.294962     1037.645221     1217.032994
# Burundi                       463.115148      446.403513      430.070692
# Cameroon                     1694.337469     1934.011449     2042.095240
# Central African Republic      740.506332      738.690607      706.016537
# Chad                         1004.961353     1156.181860     1704.063724
# Comoros                      1173.618235     1075.811558      986.147879
# Congo, Dem. Rep.              312.188423      241.165876      277.551859
# Congo, Rep.                  3484.164376     3484.061970     3632.557798
# Cote d'Ivoire                1786.265407     1648.800823     1544.750112
# Djibouti                     1895.016984     1908.260867     2082.481567
# Egypt                        4173.181797     4754.604414     5581.180998
# Equatorial Guinea            2814.480755     7703.495900    12154.089750
# Eritrea                       913.470790      765.350001      641.369524
# Ethiopia                      515.889401      530.053532      690.805576
# Gabon                       14722.841880    12521.713920    13206.484520
# Gambia                        653.730170      660.585600      752.749726
# Ghana                        1005.245812     1111.984578     1327.608910
# Guinea                        869.449767      945.583584      942.654211
# Guinea-Bissau                 796.664468      575.704718      579.231743
# Kenya                        1360.485021     1287.514732     1463.249282
# Lesotho                      1186.147994     1275.184575     1569.331442
# Liberia                       609.173951      531.482368      414.507341
# Libya                        9467.446056     9534.677467    12057.499280
# Madagascar                    986.295896      894.637082     1044.770126
# Malawi                        692.275810      665.423119      759.349910
# Mali                          790.257985      951.409752     1042.581557
# Mauritania                   1483.136136     1579.019543     1803.151496
# Mauritius                    7425.705295     9021.815894    10956.991120
# Morocco                      2982.101858     3258.495584     3820.175230
# Mozambique                    472.346077      633.617947      823.685621
# Namibia                      3899.524260     4072.324751     4811.060429
# Niger                         580.305209      601.074501      619.676892
# Nigeria                      1624.941275     1615.286395     2013.977305
# Reunion                      6071.941411     6316.165200     7670.122558
# Rwanda                        589.944505      785.653765      863.088464
# Sao Tome and Principe        1339.076036     1353.092390     1598.435089
# Senegal                      1392.368347     1519.635262     1712.472136
# Sierra Leone                  574.648158      699.489713      862.540756
# Somalia                       930.596428      882.081822      926.141068
# South Africa                 7479.188244     7710.946444     9269.657808
# Sudan                        1632.210764     1993.398314     2602.394995
# Swaziland                    3876.768460     4128.116943     4513.480643
# Tanzania                      789.186223      899.074211     1107.482182
# Togo                          982.286924      886.220577      882.969944
# Tunisia                      4876.798614     5722.895655     7092.923025
# Uganda                        816.559081      927.721002     1056.380121
# Zambia                       1071.353818     1071.613938     1271.211593
# Zimbabwe                      792.449960      672.038623      469.709298
#
#                               pop2007  lifeExp2007
# country
# Algeria                    33333216.0       72.301
# Angola                     12420476.0       42.731
# Benin                       8078314.0       56.728
# Botswana                    1639131.0       63.622
# Burkina Faso               14326203.0       52.295
# Burundi                     8390505.0       49.580
# Cameroon                   17696293.0       54.985
# Central African Republic    4369038.0       50.485
# Chad                       10238807.0       51.724
# Comoros                      710960.0       65.152
# Congo, Dem. Rep.           64606759.0       47.804
# Congo, Rep.                 3800610.0       57.470
# Cote d'Ivoire              18013409.0       54.655
# Djibouti                     496374.0       54.791
# Egypt                      80264543.0       71.338
# Equatorial Guinea            551201.0       51.579
# Eritrea                     4906585.0       58.040
# Ethiopia                   76511887.0       52.947
# Gabon                       1454867.0       61.366
# Gambia                      1688359.0       59.448
# Ghana                      22873338.0       60.022
# Guinea                      9947814.0       56.007
# Guinea-Bissau               1472041.0       46.388
# Kenya                      35610177.0       59.339
# Lesotho                     2046772.0       59.685
# Liberia                     3193942.0       46.027
# Libya                       6036914.0       73.952
# Madagascar                 19167654.0       59.443
# Malawi                     13327079.0       49.420
# Mali                       12031795.0       54.467
# Mauritania                  3270065.0       64.164
# Mauritius                   1250882.0       72.801
# Morocco                    33757175.0       71.164
# Mozambique                 19951656.0       46.344
# Namibia                     2055080.0       61.999
# Niger                      12894865.0       56.867
# Nigeria                   135031164.0       47.472
# Reunion                      798094.0       76.442
# Rwanda                      8860588.0       46.242
# Sao Tome and Principe        199579.0       65.528
# Senegal                    12267493.0       63.062
# Sierra Leone                6144562.0       42.568
# Somalia                     9118773.0       48.159
# South Africa               44433622.0       61.888
# Sudan                      42292929.0       58.556
# Swaziland                   1133066.0       58.474
# Tanzania                   38139640.0       52.517
# Togo                        5701579.0       58.420
# Tunisia                    10276158.0       73.923
# Uganda                     29170398.0       51.542
# Zambia                     11746035.0       51.821
# Zimbabwe                   12311143.0       62.351

# %% [markdown]
# ## Inspecting Data
# We've already see how we can get information about a dataframe using the `.info()` and `.describe()` functions, but there are many ways to get information and view a data frame

# %% [markdown]
# * Can also use describe() on data frame selections (like a single column)

# %%
# Use the .describe() function on the "gdpPercap" column
df_africa.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1           pop  gdpPercap_1952  \
# count    52.000000     52.000000  5.200000e+01       52.000000
# mean    845.000000    845.000000  1.788480e+07     1252.572466
# std     493.735819    493.735819  2.492633e+07      982.952116
# min      35.000000     35.000000  1.995790e+05      298.846212
# 25%     416.000000    416.000000  2.909226e+06      534.990554
# 50%     905.000000    905.000000  1.009331e+07      987.025569
# 75%    1298.000000   1298.000000  1.936365e+07     1454.886645
# max    1703.000000   1703.000000  1.350312e+08     4725.295531
#
#        gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      1385.236062     1598.078825     2050.363801     2339.615674
# std       1134.508918     1461.839189     2847.717603     3286.853884
# min        335.997115      355.203227      412.977514      464.099504
# 25%        606.954355      673.329046      779.815648      815.919804
# 50%       1024.022987     1133.783677     1210.376379     1443.372508
# 75%       1573.040442     1702.219247     1890.112274     2292.258613
# max       5487.104219     6757.030816    18772.751690    21011.497210
#
#        gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      2585.938508     2481.592960     2282.668991     2281.810333
# std       4142.398707     3242.632753     2566.531947     2644.075602
# min        502.319733      462.211415      389.876185      410.896824
# 25%        805.612125      828.656854      764.598759      743.908497
# 50%       1399.638836     1323.728306     1219.585563     1161.631357
# 75%       2841.282025     2787.582271     2786.310885     2707.896077
# max      21951.211760    17364.275380    11864.408440    13522.157520
#
#        gdpPercap_1997  gdpPercap_2002  gdpPercap_2007       pop2007  \
# count       52.000000       52.000000       52.000000  5.200000e+01
# mean      2378.759555     2599.385159     3089.032605  1.788480e+07
# std       2820.728117     2972.651308     3618.163491  2.492633e+07
# min        312.188423      241.165876      277.551859  1.995790e+05
# 25%        791.901966      780.577824      862.951537  2.909226e+06
# 50%       1179.883114     1215.683217     1452.267078  1.009331e+07
# 75%       2856.386031     3314.887180     3993.501583  1.936365e+07
# max      14722.841880    12521.713920    13206.484520  1.350312e+08
#
#        lifeExp2007
# count    52.000000
# mean     57.424904
# std       8.539196
# min      42.568000
# 25%      51.569750
# 50%      57.168500
# 75%      62.087000
# max      76.442000

# %% [markdown]
# * We can print the first or last x number of rows of our data frame using the head() and tails() functions.

# %%
# heads() function
df_africa.head()
# Out:
#         country  Unnamed: 0  Unnamed: 0.1         pop continent  \
# 0       Algeria          35            35  33333216.0    Africa
# 1        Angola          47            47  12420476.0    Africa
# 2         Benin         131           131   8078314.0    Africa
# 3      Botswana         167           167   1639131.0    Africa
# 4  Burkina Faso         203           203  14326203.0    Africa
#
#    gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0     2449.008185     3013.976023     2550.816880     3246.991771
# 1     3520.610273     3827.940465     4269.276742     5522.776375
# 2     1062.752200      959.601080      949.499064     1035.831411
# 3      851.241141      918.232535      983.653976     1214.709294
# 4      543.255241      617.183465      722.512021      794.826560
#
#    gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# 0     4182.663766     4910.416756     5745.160213     5681.358539
# 1     5473.288005     3008.647355     2756.953672     2430.208311
# 2     1085.796879     1029.161251     1277.897616     1225.856010
# 3     2263.611114     3214.857818     4551.142150     6205.883850
# 4      854.735976      743.387037      807.198586      912.063142
#
#    gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007     pop2007  \
# 0     5023.216647     4797.295051     5288.040382     6223.367465  33333216.0
# 1     2627.845685     2277.140884     2773.287312     4797.231267  12420476.0
# 2     1191.207681     1232.975292     1372.877931     1441.284873   8078314.0
# 3     7954.111645     8647.142313    11003.605080    12569.851770   1639131.0
# 4      931.752773      946.294962     1037.645221     1217.032994  14326203.0
#
#    lifeExp2007
# 0       72.301
# 1       42.731
# 2       56.728
# 3       63.622
# 4       52.295

# %%
# tails() function
df_africa.tail()
# Out:
#      country  Unnamed: 0  Unnamed: 0.1         pop continent  gdpPercap_1952  \
# 47      Togo        1547          1547   5701579.0    Africa      859.808657
# 48   Tunisia        1571          1571  10276158.0    Africa     1468.475631
# 49    Uganda        1595          1595  29170398.0    Africa      734.753484
# 50    Zambia        1691          1691  11746035.0    Africa     1147.388831
# 51  Zimbabwe        1703          1703  12311143.0    Africa      406.884115
#
#     gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  \
# 47      925.908320     1067.534810     1477.596760     1649.660188
# 48     1395.232468     1660.303210     1932.360167     2753.285994
# 49      774.371069      767.271740      908.918522      950.735869
# 50     1311.956766     1452.725766     1777.077318     1773.498265
# 51      518.764268      527.272182      569.795071      799.362176
#
#     gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# 47     1532.776998     1344.577953     1202.201361     1034.298904
# 48     3120.876811     3560.233174     3810.419296     4332.720164
# 49      843.733137      682.266227      617.724406      644.170797
# 50     1588.688299     1408.678565     1213.315116     1210.884633
# 51      685.587682      788.855041      706.157306      693.420786
#
#     gdpPercap_1997  gdpPercap_2002  gdpPercap_2007     pop2007  lifeExp2007
# 47      982.286924      886.220577      882.969944   5701579.0       58.420
# 48     4876.798614     5722.895655     7092.923025  10276158.0       73.923
# 49      816.559081      927.721002     1056.380121  29170398.0       51.542
# 50     1071.353818     1071.613938     1271.211593  11746035.0       51.821
# 51      792.449960      672.038623      469.709298  12311143.0       62.351

# %% [markdown]
# * **Note:** head() and tail() default to 5 rows worth of data. We can also pass a value to either to get more or less rows.
#   * E.g.
#   head(10)
#
#  ---
#
# * Use `.dtypes` method to get the data type for each column

# %%
# Write your code here

# %% [markdown]
# * Use `shape` method to get the row and column numbers

# %%
# Write your code here

# %% [markdown]
# Here we can see the that the data have 52 rows of data and 18 attributes worth of information.
#
# * Use the `len()` function to get numbers of each individually

# %%
# print number of rows of data

# %%
# print number of columns of data

# %% [markdown]
# * As seen before we can pass the data frame a column name to get all values for that column
#
#
# * Print out only the lifeExp2007 column from the data frame

# %%
# Write your code here

# %% [markdown]
# ---
# ## EXERCISE:
# 1. How many different country names are there in the gapminder_all.csv file?
#
# ---

# %%
# Write your code here

# %% [markdown]
# ---
# ## EXERCISE:
# 1. What is the last country listed in the Africa data frame?
#
# ---

# %%
# Write your code here

# %% [markdown]
# ---
# ## Get information about a particular column
#
# * Operations like mean, max, min, can be used on individual columns
#   * E.g. `df['year'].min()`

# %%
# What is the minimum value in the year column?

# %% [markdown]
# ---
# ## EXERCISE:
# 1. What is the mean life expectancy in 2007 for all countries in all years
#
# 1. What is the max population in 2007 for all countries in all years
#
# 1. What is the standard deviation for GDP per capita for all countries in all years

# %%
df = pd.read_csv("../data/processed_data/gapminder_all.csv")
# Mean Life Expectancy in 2007

# Max Population in 2007

# Standard Deviation of GDP per capita in 1952

# %% [markdown]
# ## Rearange Columns
#
# * This is difficult to do using a csv library or by hand
# * The reverse() function will reverse the ordering of a list
#      * E.g.   `['a', 'b', 'c']` to `['c', 'b', 'a']`

# %%
# Use the python list() function to get the data frame columns a s list
cols = list(df.columns)
print( cols )

# use the .reverse() function to reverse the ordering of the columns

print ( cols )

# %% [markdown]
# * Using that now reversed list above, we can pass the list to the new data frame to reorder the columns

# %%
# Pass the cols variable to the data frame to re-arrange the columns

# %% [markdown]
# ## Transposing tables
#
# In many cases we may need to transpose the column and rows in a table.  Pandas allows us to to this easily with the `T` command.

# %%
# Print first three rows of the data frame

# Transpose the dataframe and print the first three rows

# %% [markdown]
# ---
# ## EXERCISE:
# 1. Read in a new data frame for the gapminder_Americas.csv file
# 2. Print the last last three columns of the data frame

# %% [markdown]
# ---
# ## Selecting values
#
# Data Frames provides a index as a way to identify the rows of the table. A row also has a position inside the table as well as a label, which uniquely identifies its entry in the DataFrame.
#
# To access a value at the position [ i , j ] (row, column) of a Data Frame, we have two options, depending on what is the meaning of i in use.

# %% [markdown]
# ### Use DataFrame.iloc[..., ...] to select values by their position
# * Allows you to specify location by numerical index similar to 2D version of character selection in strings.

# %%
print("\nData value in first row at first column: ", df.iloc[0, 0])

# %%
print("\nData value in fifth row at third column: ", df.iloc[4, 2])

# %% [markdown]
# ### Use `DataFrame.loc[..., ...]` to select values by their (index) label.
#
# *   Can specify location by name or by numerical index.

# %%
# Print the value of Albanias GDP per capita in 1952 using .loc

# %%
# Print the value of Bulgarias GDP per capita in 1962 using .loc

# %% [markdown]
# ---
# ## EXERCISE
# ~~~
# import pandas
# df = pandas.read_csv('data/gapminder_Europe.csv', index_col='country')
# ~~~
#
# 1. Find the Per Capita GDP for Serbia in 2007.
# 1. Find the Per Capita GDPs for Germany in 1982

# %%
# Write your code here

# %% [markdown]
# ---
# ## Slicing Data Frames
#
# ### Use `:` on its own to mean all columns or all rows.
#
# *   Just like Python's usual slicing notation, we can print all columns or all rows with `.loc` using the `:`

# %%
# Print all of the row values for all years for Egypt

# %% [markdown]
# * Would get the same result printing `df.iloc[0]` (without a second index).
# * We can also omit the `:` and get all rows.
#     * e.g. `df.loc["Albania"]`

# %%
# Print the GDP per capita for all countries in 1952

# %% [markdown]
# *   Would get the same result printing `df["gdpPercap_1952"]`
# *   Also get the same result printing `df.gdpPercap_1952` (since it's a column name)

# %% [markdown]
# ---
# ## EXERCISE:
# 1. Print out GDP per capita for all countries in asia in 1972

# %%
# Write your code here

# %% [markdown]
# ---
# ### We can also use the `:` to select whole sections of a table
# * Similar to the way we would select a section of from a normal python list, we can do the same with data frames.

# %%
# Print a selection of all countries in the table from Italy to Poland from years 1962 to 1972

# %% [markdown]
# Note that in Pandas **slicing using indexes is inclusive at both ends**, which differs from typical python behavior where slicing indicates everything up to but not including the final index.

# %% [markdown]
# ### Select multiple columns or rows using `DataFrame.iloc` and a named slice.
# * We can also make selection from a data frame using the index location of the row or column
#     * Remember that in programming languages, we start counting at 0

# %%
#Print the first row of the data frame using the .head() function
print("First row of data frame:\n",  )

# Use iloc to print the value in the first row of the first column
print("\n\nValue in the first row of the first column:\n",  )

# Use iloc to print the values of the first two columns in the first row
print("Values in the first two columes in the first row:\n",  )

# %% [markdown]
# * **Note that unlike slicing using column or row names, slicing using indexes is not inclusive**

# %% [markdown]
# ---
# ## EXERCISE:
# 1. Print out all values from Hungary through Montenegro (Europe data) for the years 1977 through 1997

# %%
# Write code here

# %% [markdown]
# ---
# ## EXERCISE:
# 1.  Do the two statements below produce the same output?
#     ~~~
#     print(df.iloc[0:2, 0:2])
#     print(df.loc['Albania':'Belgium', 'gdpPercap_1952':'gdpPercap_1962'])
#     ~~~
#
# 1.  Based on this,what rule governs what is included (or not) in numerical slices and named slices in Pandas?

# %% [markdown]
# ---
# ### Slicing individual rows and columns
# * Instead of creating slices of *this* to *that* using the `:`, we can also slice using individual rows and columns by placing names or indexes in brackets `[]`.

# %%
# Print out the GDP per capita of only Italy, Austria, and the United Kingdom in the years 2007 and 1957

# %% [markdown]
# ---
# ## EXERCISE:
# 1. Using the index locations, `print` out the first, third, and eight columns for the sixteenth through nineteenth rows.

# %% [markdown]
# ---
# ## Result of slicing can be used in further operations.

# %%
# Print out the max value (.max()) of ALL countries from Italy to Poland for 1962 to 1972

# %%
# Print out the min value (.min()) of ALL countries from Italy to Poland for 1962 to 1972

# %% [markdown]
# *   Usually don't just print a slice.
# *   All the statistical operators that work on entire data frames work the same way on slices.

# %% [markdown]
# ## Create data frame from selections
#
# * We can create new data frame by selecting data frames based on values and assigining it to a variable

# %%
# Create a selection of ALL countries from Italy to Poland for 1962 to 1972 and 
#  assign the selection to a variable name "subset_df"

print('Subset of data:\n', subset_df)

# %% [markdown]
# ## Create DataFrame using query
# * We can query values in a data frame to create new selections
# * By passing a dataframe query to itself, we can create a new dataframe with only those values

# %%
# Create a query for the "gdpPerCap_1962" series in out subset_df data frame for all values greater than 10000

# Create a new data frame called subset_10k_df by passing that query to the subset_df data frame


print(query_10k)
print(subset_10k_df)
print(subset_10k_df.shape)

# %% [markdown]
# ---
# ## EXERCISE:
#
# * Create three data frames and get the size of each one.
#     1. Countries with a gdp per capita in 1952 above 10000
#     1. Countries with a gdp per capita in 1962 above 10000
#     1. Countries with a gdp per capita in 1972 above 10000
#
# ---

# %% [markdown]
# ## Filter a DataFrame using a Boolean mask
#
# * A frame full of Booleans is sometimes called a *mask* because of how it can be used
# * Comparison is applied element by element
# * Returns a similarly-shaped data frame of `True` and `False`

# %%
# Create a full data frame mask for subset_df with a query for all values in all years greater than 10000
mask_10k = 

print( mask_10k )

# %% [markdown]
# * We can use masks to filter an entire dataframe with a single query
#     * More efficient than using a single query on multiple columns

# %%
# Pass the mask query to subset_df to create a new data frame mask_subset
mask_subset = 

print(mask_subset)
print("Shape: ", mask_subset.shape)

# %% [markdown]
# *   Returns the value where the mask is true, and NaN (Not a Number) where it is false.
# *   Useful because NaNs are ignored by operations like max, min, average, etc.
#
#
# * If we wanted to remove all rows with a NaN value in any column we could use the `.dropna()` function

# %%
# Print the mask_subset data frame with all rows with a single NaN value removed


# Print the shape of the mask_subset data frame with all rows with an NaN values removed

# %% [markdown]
# ## Create new columns
#
# * We can easily create new columns in the same way we would add a key and value to a dictionary

# %%
# Create a new column in data frame called diff_07_52 that is the difference between gdp per capita from 1952 to 2007


print(df.head(1))

# %% [markdown]
# ---
# ## EtherPad
#
# On EtherPad explain what the follow expression does:
#
#     only_Am = df[df['continent'] == 'Americas']
#
# ___

# %% [markdown]
# ## EXERCISE:
# 1. Explain in simple terms what `idxmin` and `idxmax` do in the short program below.
#     ~~~
#     df = pd.read_csv('data/gapminder_gdp_europe.csv', index_col='country')
#     print(df.idxmin())
#     print(df.idymax())
#     ~~~
#
# 2. When would you use these methods?

# %% [markdown]
# ---
# ## PRACTICE EXERCISE.
# Using the Gapminder GDP data for Europe, write an expression to select each of the following:
# 1.  GDP per capita for all countries in 1982.
# 1.  GDP per capita for Denmark for all years.
# 1.  GDP per capita for all countries for years *after* 1985.
# 1.  GDP per capita for each country in 2007 as a multiple of GDP per capita for that country in 1952.
# ---

# %% [markdown]
# # -- COMMIT YOUR WORK TO GITHUB --

# %% [markdown]
# ---
# ## Keypoints:
#  - "Use `DataFrame.iloc[..., ...]` to select values by index location."
#  - "Use `:` on its own to mean all columns or all rows."
#  - "Select multiple columns or rows using `DataFrame.ix` and a named slice."
#  - "Result of slicing can be used in further operations."
#  - "Use comparisons to select data based on value."
#  - "Select values or NaN using a Boolean mask."
